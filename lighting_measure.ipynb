# %%
from openstudio_measures import modify_lpd_in_all_zones

# relative path to folder containing osm files relevant for the assignment
osm_folder_path = 'osm_files'

# lighting Power Density in Watts per Space Floor Area {W/m2}
target_ldp = 10 

modify_lpd_in_all_zones(osm_folder_path, target_ldp)
